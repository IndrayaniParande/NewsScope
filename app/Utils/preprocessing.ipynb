# %%
import pandas as pdd

df = pdd.read_csv("app/collector/newsapi_daily_data/")
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# source          0
# author         41
# title           0
# description    14
# url             0
# urlToImage     43
# publishedAt     0
# content         0
# topic           0
# dtype: int64
# 0
